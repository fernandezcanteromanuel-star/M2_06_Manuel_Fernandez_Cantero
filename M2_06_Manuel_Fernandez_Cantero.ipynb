# %%
#Radio del círculo
from math import pi


def area_circulo(radio):
    return pi*radio*radio

radio = float(input('Radio del círculo: '))

area_circulo(radio)
# Out:
# 78.53981633974483

# %%
#Mayor()

def lee_numero():
    n = int(input('Quién es Diego sniper?: '))
    i = 0
    lista = []
    while i < n:
        numero = float(input('Número: '))
        lista.append(numero)
        i += 1
    return lista

def mayor(lista):
    lista.sort()
    print(lista)
    return lista[-1]

a = lee_numero()

mayor(a)
# Out:
# [7.0, 8.0, 9.0, 2413.0, 2342341.0]
# 2342341.0

# %%
#Indice de masa corporal

def imc(peso, altura):
    global a
    a = float(peso/(altura*altura))
    if a < 18.5:
        print('Desnutrido')
    elif a >= 18.5 and a < 25.0:
        print('Normal')
    elif a >= 25.0 and a < 30.0:
        print('Gordito')
    else:
        print('Obesidad mórbida')


peso = float(input('Introduzca su peso: '))
altura = float(input('Introduzca su altura: '))

imc(peso, altura)
print('Tu peso es: {}kg y tu altura es {}m, por tanto tu imc es: {}'.format(peso, altura, round(a, 2)))
# Out:
# Desnutrido
# Tu peso es: 55.0kg y tu altura es 1.8m, por tanto tu imc es: 16.98
